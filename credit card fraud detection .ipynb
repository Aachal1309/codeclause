# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data= pd.read_csv("C:/Users/user/Downloads/archive/creditcard.csv")

# %% [markdown]
# # Analysing data

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
print(data.shape)
# Out:
# (284807, 31)

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Time      124592
# V1        275663
# V2        275663
# V3        275663
# V4        275663
# V5        275663
# V6        275663
# V7        275663
# V8        275663
# V9        275663
# V10       275663
# V11       275663
# V12       275663
# V13       275663
# V14       275663
# V15       275663
# V16       275663
# V17       275663
# V18       275663
# V19       275663
# V20       275663
# V21       275663
# V22       275663
# V23       275663
# V24       275663
# V25       275663
# V26       275663
# V27       275663
# V28       275663
# Amount     32767
# Class          2
# dtype: int64

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
data.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16
# V2     -0.010593  4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15
# V3     -0.419618 -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16
# V4     -0.105260 -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15
# V6     -0.063016 -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16
# V7      0.084714 -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16
# V8     -0.036949 -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16
# V9     -0.008660 -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16
# V11    -0.247689  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %% [markdown]
# # distribution of clean transactions & fraudulent transactions

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# 0 - normal and clean trasaction
# 1 - fraudulent transactions

# %% [markdown]
# # checking for null values

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
normal_transaction= data[data.Class ==0]
fraud_transaction = data[data.Class ==1]

# %%
print(normal_transaction.shape)
print(fraud_transaction.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
import seaborn as sns

# %%
sns.countplot(data["Class"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
normal_transaction.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud_transaction.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# # Under-Sampling of dataset

# %%
new_normal_transaction =normal_transaction.sample(n=492)

# %%
new_data= pd.concat ([new_normal_transaction , fraud_transaction] , axis =0)

# %% [markdown]
# # Analysing new dataset formed

# %%
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 109761   71528.0  1.313228  0.106828 -0.011085 -0.097668 -0.048913 -0.643367
# 130239   79313.0  1.146714 -0.034448  0.136934  0.056346 -0.476175 -1.111873
# 23758    32901.0 -1.069024  0.390284  1.685461  0.861325  0.020557  0.828191
# 184710  126353.0  2.026226  0.152387 -1.740240  1.181536  0.637319 -0.611756
# 76002    56351.0  1.162255 -2.088343  0.774121 -1.043649 -1.836651  1.117775
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 109761  0.152170 -0.265892  0.003448  ... -0.258264 -0.730141 -0.025630
# 130239  0.252675 -0.169029 -0.271494  ... -0.354384 -1.248311  0.183584
# 23758  -0.762973  0.932616 -0.247925  ...  0.347646  0.881769 -0.243925
# 184710  0.487696 -0.214799  0.051524  ...  0.065237  0.372803 -0.051319
# 76002  -1.667059  0.359494 -0.528251  ... -0.407572 -0.729973 -0.221547
#
# ...

# %%
new_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_data.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     984.000000  984.000000  984.000000  984.000000  984.000000
# mean    86732.401423   -2.432753    1.787494   -3.504237    2.248690
# std     47085.034124    5.550719    3.783447    6.241043    3.220015
# min       406.000000  -30.552380  -21.510079  -31.103685   -4.848504
# 25%     46508.500000   -2.784711   -0.105563   -5.113334   -0.105843
# 50%     78176.000000   -0.878721    0.951586   -1.302195    1.352329
# 75%    131789.500000    0.951945    2.793742    0.381500    4.184137
# max    172507.000000    2.220453   22.057729    3.545610   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  984.000000  984.000000  984.000000  984.000000  984.000000  ...
# mean    -1.595986   -0.628770   -2.747328    0.226746   -1.282669  ...
# std      4.271809    1.857324    5.925096    4.893198    2.345669  ...
# ...

# %%
new_data.shape
# Out:
# (984, 31)

# %%
new_data["Class"].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_data.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92717.995935 -0.093557 -0.048790  0.024808 -0.044650 -0.040748
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.140197  0.074076 -0.117144  0.015786  ... -0.054296 -0.027377
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.010434 -0.080790 -0.042875  0.009455  0.013932 -0.005416  0.022106
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0      107.506118
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# # Creating dependent and independent variables

# %%
X= new_data.drop(columns='Class',axis=1)
Y=new_data['Class']

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 109761   71528.0  1.313228  0.106828 -0.011085 -0.097668 -0.048913 -0.643367
# 130239   79313.0  1.146714 -0.034448  0.136934  0.056346 -0.476175 -1.111873
# 23758    32901.0 -1.069024  0.390284  1.685461  0.861325  0.020557  0.828191
# 184710  126353.0  2.026226  0.152387 -1.740240  1.181536  0.637319 -0.611756
# 76002    56351.0  1.162255 -2.088343  0.774121 -1.043649 -1.836651  1.117775
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
Y
# Out:
# 109761    0
# 130239    0
# 23758     0
# 184710    0
# 76002     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
Scaler= StandardScaler()

# %%
X_train, X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train= Scaler.fit_transform(X_train)

# %%
X_test= Scaler.fit_transform(X_test)

# %%
print( X.shape ,X_train.shape , X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
print( Y.shape ,Y_train.shape , Y_test.shape)
# Out:
# (984,) (787,) (197,)

# %% [markdown]
# # Logistic Regression

# %%
clf= LogisticRegression()

# %%
#Training Model

# %%
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
X_train_predict =clf.predict(X_train)
training_data_accuracy=accuracy_score(X_train_predict ,Y_train)

# %%
print("the accuracy score on training dataset is ", training_data_accuracy)
# Out:
# the accuracy score on training dataset is  0.9529860228716646

# %%
X_test_predict =clf.predict(X_test)
test_data_accuracy=accuracy_score(X_test_predict ,Y_test)

# %%
print("the accuracy score on test dataset is ", test_data_accuracy)
# Out:
# the accuracy score on test dataset is  0.9441624365482234
